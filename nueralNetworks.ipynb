# %% [markdown]
# Neural Networks

# %% [markdown]
# -Tensor Flow

# %%
pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/284.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/284.2 MB ? eta -:--:--
#      -------------------------------------- 0.0/284.2 MB 330.3 kB/s eta 0:14:21
#      -------------------------------------- 0.0/284.2 MB 330.3 kB/s eta 0:14:21
#      -------------------------------------- 0.0/284.2 MB 164.3 kB/s eta 0:28:50
#      -------------------------------------- 0.0/284.2 MB 164.3 kB/s eta 0:28:50
#      -------------------------------------- 0.1/284.2 MB 204.8 kB/s eta 0:23:08
#      -------------------------------------- 0.1/284.2 MB 328.2 kB/s eta 0:14:26
#      -------------------------------------- 0.1/284.2 MB 328.2 kB/s eta 0:14:26
#      -------------------------------------- 0.2/284.2 MB 353.1 kB/s eta 0:13:25
#      -------------------------------------- 0.2/284.2 MB 361.7 kB/s eta 0:13:06
#      -------------------------------------- 0.2/284.2 MB 368.6 kB/s eta 0:12:51
# ...

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\dharmik\Desktop\python\ML\nueralNetworks.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dharmik/Desktop/python/ML/nueralNetworks.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
